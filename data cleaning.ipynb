# %% [markdown]
# # TECHNOHACKS TASK-1

# %% [markdown]
# ## DATA CLEANING

# %%
pip install pandas xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('sample sales data.xls',engine='xlrd')
data
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
choose_columns=data[['City','State','Postal Code','Category','Sales','Quantity','Discount','Profit']]
choose_columns
# Out:
#                  City       State  Postal Code         Category     Sales  \
# 0           Henderson    Kentucky        42420        Furniture  261.9600
# 1           Henderson    Kentucky        42420        Furniture  731.9400
# 2         Los Angeles  California        90036  Office Supplies   14.6200
# 3     Fort Lauderdale     Florida        33311        Furniture  957.5775
# 4     Fort Lauderdale     Florida        33311  Office Supplies   22.3680
# ...               ...         ...          ...              ...       ...
# 9989            Miami     Florida        33180        Furniture   25.2480
# 9990       Costa Mesa  California        92627        Furniture   91.9600
# 9991       Costa Mesa  California        92627       Technology  258.5760
# 9992       Costa Mesa  California        92627  Office Supplies   29.6000
# 9993      Westminster  California        92683  Office Supplies  243.1600
#
#       Quantity  Discount    Profit
# 0            2      0.00   41.9136
# ...

# %%
data=data.drop(['Row ID','Order ID','Order Date','Ship Date','Ship Mode','Customer Name'],axis=1)
data
# Out:
#      Customer ID    Segment        Country             City       State  \
# 0       CG-12520   Consumer  United States        Henderson    Kentucky
# 1       CG-12520   Consumer  United States        Henderson    Kentucky
# 2       DV-13045  Corporate  United States      Los Angeles  California
# 3       SO-20335   Consumer  United States  Fort Lauderdale     Florida
# 4       SO-20335   Consumer  United States  Fort Lauderdale     Florida
# ...          ...        ...            ...              ...         ...
# 9989    TB-21400   Consumer  United States            Miami     Florida
# 9990    DB-13060   Consumer  United States       Costa Mesa  California
# 9991    DB-13060   Consumer  United States       Costa Mesa  California
# 9992    DB-13060   Consumer  United States       Costa Mesa  California
# 9993    CC-12220   Consumer  United States      Westminster  California
#
#       Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000
